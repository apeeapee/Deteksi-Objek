# %% [markdown]
# <a href="https://colab.research.google.com/github/apeeapee/Deteksi-Objek/blob/main/YOLOv11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# UPLOAD DATASET

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0142ea72-30be-4ba7-a1e9-4c2f16ed259d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0142ea72-30be-4ba7-a1e9-4c2f16ed259d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# EKSTRAK DATASET

# %%
# !unzip "Car detection.v1i.yolov11" -d dataset
# Out:
# Archive:  Car detection.v1i.yolov11.zip
#   inflating: dataset/README.dataset.txt
#   inflating: dataset/README.roboflow.txt
#   inflating: dataset/data.yaml
#    creating: dataset/test/
#    creating: dataset/test/images/
#  extracting: dataset/test/images/00001_jpg.rf.cbbe12a754843c7186b34605e4d223d9.jpg
#  extracting: dataset/test/images/00023_jpg.rf.1d5f0d2bbce317c08ddd8016ba24b00d.jpg
#  extracting: dataset/test/images/00024_jpg.rf.f28c169fdce39b5959f7dd65cb7109cc.jpg
#  extracting: dataset/test/images/00045_jpg.rf.617ee6caa0903e2af0628e38d8063663.jpg
#  extracting: dataset/test/images/00117_jpg.rf.00fb088ebbb54dcf26775ee1bd1d4cf7.jpg
#  extracting: dataset/test/images/00246_jpg.rf.22a66dff78e0fa0c5a258fbfefad0ac1.jpg
#  extracting: dataset/test/images/00248_jpg.rf.67769d207e08d1b5b6a2901e402358d0.jpg
#  extracting: dataset/test/images/00252_jpg.rf.622a360f91d8e23d0113f565d8abd963.jpg
#  extracting: dataset/test/images/00254_jpg.rf.bd5e9c28ea0f32dbb0241778060cab2a.jpg
# ...

# %% [markdown]
# Training YOLO v11

# %%
#install yolo
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 23.0 MB/s eta 0:00:00
# ...

# %%
#load yolo v11
from ultralytics import YOLO
model = YOLO("yolo11n.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %% [markdown]
# Banyak data testing dan data training

# %%
# !ls /content/dataset/test/images | wc -l
# !ls /content/dataset/train/images | wc -l
# Out:
# 282
# 1121

# %% [markdown]
# Training Data

# %%
model.train(
    data="/content/dataset/data.yaml",
    epochs=30,
    imgsz=512,
    batch=8
)
# Out:
# Ultralytics 8.3.234 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# Testing Gambar

# %%
# !ls
# Out:
# 'Car detection.v1i.yolov11.zip'  'Foto Testing.jfif'   runs	     yolo11n.pt
#  dataset			  FotoTesting.jpg      sample_data

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e30f9845-4e25-4bdd-b307-9ff7063c7f11" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e30f9845-4e25-4bdd-b307-9ff7063c7f11">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
model.predict("FotoTesting.jpg", save=True)
# Out:
# image 1/1 /content/FotoTesting.jpg: 352x512 11 cars, 50.4ms
# Speed: 2.6ms preprocess, 50.4ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 512)
# Results saved to /content/runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Car', 1: 'TL', 2: 'bicycle', 3: 'bike', 4: 'bus', 5: 'car', 6: 'cng', 7: 'easybike', 8: 'person', 9: 'rickshaw', 10: 'tractor', 11: 'truck'}
#  obb: None
#  orig_img: array([[[  5,  10,   9],
#          [  4,   9,   8],
#          [  3,   8,   7],
#          ...,
#          [ 18,  13,  14],
#          [ 18,  13,  14],
#          [ 18,  13,  14]],
#
#         [[  3,   8,   7],
#          [  3,   8,   7],
#          [  3,   8,   7],
#          ...,
#          [  6,   4,   4],
#          [  6,   4,   4],
#          [  6,   4,   4]],
#
#         [[  2,   7,   6],
#          [  2,   7,   6],
#          [  3,   8,   7],
# ...

# %% [markdown]
# Testing Video

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1c4a7b44-9647-4d30-8c21-02b34560f0e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1c4a7b44-9647-4d30-8c21-02b34560f0e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
model.predict(source="VidTesting.mp4", save=True)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/732) /content/VidTesting.mp4: 288x512 18 cars, 187.3ms
# video 1/1 (frame 2/732) /content/VidTesting.mp4: 288x512 16 cars, 9.8ms
# video 1/1 (frame 3/732) /content/VidTesting.mp4: 288x512 15 cars, 10.5ms
# video 1/1 (frame 4/732) /content/VidTesting.mp4: 288x512 16 cars, 9.8ms
# video 1/1 (frame 5/732) /content/VidTesting.mp4: 288x512 15 cars, 9.5ms
# ...
